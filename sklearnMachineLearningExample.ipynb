# %% [markdown]
# <a href="https://colab.research.google.com/github/LindseyShantanu/AI-ML-Dev/blob/main/sklearnMachineLearningExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
sns.set()
sns.set_style('darkgrid')

# %% [markdown]
# #Load Data

# %%
bc = load_breast_cancer() #raw data
data = pd.DataFrame(bc.data, columns=bc.feature_names)
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
target = pd.DataFrame(bc.target, columns=['class']) #classifiers
target.head()
# Out:
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
train_data, test_data, train_class, test_class = train_test_split(data, target)

# %% [markdown]
# #Decision Tree

# %%
tree = DecisionTreeClassifier().fit(train_data, train_class)
tree_predict = tree.predict(test_data)

# %% [markdown]
# #Visualization

# %%
plt.figure(figsize=(16,10))
plot_tree(tree)
# Out:
# [Text(0.7171052631578947, 0.9444444444444444, 'x[23] <= 868.2\ngini = 0.46\nsamples = 426\nvalue = [153, 273]'),
#  Text(0.5394736842105263, 0.8333333333333334, 'x[27] <= 0.163\ngini = 0.153\nsamples = 288\nvalue = [24, 264]'),
#  Text(0.4868421052631579, 0.7222222222222222, 'x[27] <= 0.132\ngini = 0.089\nsamples = 277\nvalue = [13, 264]'),
#  Text(0.2894736842105263, 0.6111111111111112, 'x[18] <= 0.009\ngini = 0.032\nsamples = 248\nvalue = [4, 244]'),
#  Text(0.23684210526315788, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34210526315789475, 0.5, 'x[6] <= 0.12\ngini = 0.024\nsamples = 247\nvalue = [3, 244]'),
#  Text(0.21052631578947367, 0.3888888888888889, 'x[14] <= 0.003\ngini = 0.016\nsamples = 243\nvalue = [2, 241]'),
#  Text(0.10526315789473684, 0.2777777777777778, 'x[27] <= 0.101\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.05263157894736842, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.15789473684210525, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3157894736842105, 0.2777777777777778, 'x[21] <= 33.35\ngini = 0.008\nsamples = 237\nvalue = [1, 236]'),
#  Text(0.2631578947368421, 0.16666666666666666, 'gini = 0.0\nsamples = 225\nvalue = [0, 225]'),
#  Text(0.3684210526315789, 0.16666666666666666, 'x[21] <= 34.14\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.3157894736842105, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.42105263157894735, 0.05555555555555555, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.47368421052631576, 0.3888888888888889, 'x[1] <= 21.08\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.42105263157894735, 0.2777777777777778, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5263157894736842, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6842105263157895, 0.6111111111111112, 'x[1] <= 20.94\ngini = 0.428\nsamples = 29\nvalue = [9, 20]'),
#  Text(0.631578947368421, 0.5, 'x[23] <= 811.1\ngini = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.5789473684210527, 0.3888888888888889, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.6842105263157895, 0.3888888888888889, 'x[3] <= 610.4\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.631578947368421, 0.2777777777777778, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7368421052631579, 0.2777777777777778, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7368421052631579, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5921052631578947, 0.7222222222222222, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.8947368421052632, 0.8333333333333334, 'x[6] <= 0.072\ngini = 0.122\nsamples = 138\nvalue = [129, 9]'),
#  Text(0.8421052631578947, 0.7222222222222222, 'x[1] <= 18.835\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.7894736842105263, 0.6111111111111112, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8947368421052632, 0.6111111111111112, 'x[28] <= 0.26\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.8421052631578947, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9473684210526315, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.9473684210526315, 0.7222222222222222, 'gini = 0.0\nsamples = 123\nvalue = [123, 0]')]

# %%
print(classification_report(tree_predict, test_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        58
#            1       0.96      0.95      0.96        85
#
#     accuracy                           0.95       143
#    macro avg       0.95      0.95      0.95       143
# weighted avg       0.95      0.95      0.95       143

# %%
c = confusion_matrix(test_class, tree_predict)
plt.figure(figsize=(10,10))
ax = sns.heatmap(c.T, square=True, annot=True, fmt='d', cbar=False, xticklabels=bc.target_names, yticklabels=bc.target_names)
ax.set_xlabel('True')
ax.set_ylabel('Predicted')
# Out:
# Text(93.75, 0.5, 'Predicted')

# %% [markdown]
# #Random Forest

# %%
forest = RandomForestClassifier(n_estimators=200, max_samples=0.7).fit(train_data, train_class)
forest_predict = forest.predict(test_data)
print(classification_report(forest_predict, test_class))
# Out:
# <ipython-input-12-637cecda2490>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest = RandomForestClassifier(n_estimators=200, max_samples=0.7).fit(train_data, train_class)
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96        56
#            1       0.99      0.95      0.97        87
#
#     accuracy                           0.97       143
#    macro avg       0.96      0.97      0.96       143
# weighted avg       0.97      0.97      0.97       143

# %%
c = confusion_matrix(test_class, forest_predict)
plt.figure(figsize=(10,10))
ax = sns.heatmap(c.T, square=True, annot=True, fmt='d', cbar=False, xticklabels=bc.target_names, yticklabels=bc.target_names)
ax.set_xlabel('True')
ax.set_ylabel('Predicted')
# Out:
# Text(93.75, 0.5, 'Predicted')
